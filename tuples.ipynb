# %%
#tuples are used to store multiple items in a single variables. 
#A tuple is a collection which is ordered and unchageable.
#Tuple items are ordered, unchangeable, and allow duplicate values.
#Tuple items are indexed, the first item has a index[0], the second item has index[1] etc.

# %%
#tuple creation.

# %%
t = (1,2)
print(type(t))
print(len(t))
# Out:
# <class 'tuple'>
# 2

# %%
t = (1,2)
print(t)
# Out:
# (1, 2)

# %%
t1 = (1,2,3,4,5)
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t2 = (5,8,69,6,3)
print(type(t2))
# Out:
# <class 'tuple'>

# %%
print(len(t1))
# Out:
# 5

# %%
print(len(t2))
# Out:
# 5

# %%
a = ("a","b","c")

# %%
t3 = ("A","B","C","D","E")
print(t3)
# Out:
# ('A', 'B', 'C', 'D', 'E')

# %%
t3[3]
# Out:
# 'D'

# %%
t3[0]
# Out:
# 'A'

# %%
t3[4]
# Out:
# 'E'

# %%
t3[2:4]
# Out:
# ('C', 'D')

# %%
t3[2:]
# Out:
# ('C', 'D', 'E')

# %%
t4 = ("A","B","C","D","E")
print(t4)
# Out:
# ('A', 'B', 'C', 'D', 'E')

# %%
t4[-1]
# Out:
# 'E'

# %%
t4[-4:-2]
# Out:
# ('B', 'C')

# %%
t4[-5:-1]
# Out:
# ('A', 'B', 'C', 'D')

# %%
#create tuple with one item.
t5 = (1)
print(t5)
# Out:
# 1

# %%
print(type(t5))
# Out:
# <class 'int'>

# %%
t6 = (9,)
print(type(t6))
# Out:
# <class 'tuple'>

# %%
animals = ("deer","tiger","lion","elephant")
print(type(animals))
# Out:
# <class 'tuple'>

# %%
sports = ("volleyball", "baseball", "hockey")
print(type(sports))
# Out:
# <class 'tuple'>

# %%
names = ("Rishabh" ,"yash", "sakshi", "invida")
print(type(names))
# Out:
# <class 'tuple'>

# %%
t = (1,2,3)
t = t+(4,)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
p = (3,4,5)
p = p+(3,)
print(p)
# Out:
# (3, 4, 5, 3)

# %%
#replace..........

# %%
n = (2,3,4)
m= list(n)
m[1] = 2
n =(n)
print(m)
# Out:
# [2, 2, 4]

# %%
t2 = ("A","B","C","D","E")
y = list(t2)
y[3] = ("N")
t2 = tuple(y)
print(t2)
# Out:
# ('A', 'B', 'C', 'N', 'E')

# %%
t3 = (5,8,9,6,0)
x = list(t3)
x[2] = (3)
t3 = tuple(x)
print(t3)
# Out:
# (5, 8, 3, 6, 0)

# %%
a = (8,5,2,0)
b = list(a)
b[1] = (7)
b = tuple(a)
print(a)
# Out:
# (8, 5, 2, 0)

# %%
#addition of elements.

# %%
t = (1,2,3)
t = t+(4,)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t = list(a)
t.append(4)
print(t)
# Out:
# [5, 8, 3, 6, 0, (5, 8, 3, 6, 0), 4]

# %%
g = list(t2)
g.append(9)
print(g)
# Out:
# ['A', 'B', 'C', 'N', 'E', 9]

# %%
a1 = (9,)
a2 =( 0,6,4,3)
a1 = a1+a2
print(a1)
# Out:
# (9, 0, 6, 4, 3)

# %%
c1 = (8,)
c2 = (3,4,6,7,8)
c1 = c1 + c2
print(c1)
# Out:
# (8, 3, 4, 6, 7, 8)

# %%
v = (9,0)
v1 =(1,2,3)
v2= v+v1
print(v2)
# Out:
# (9, 0, 1, 2, 3)

# %%
#remove the itmes in tuple

# %%
y2 = list(v2)
y2.remove(1)
print(y2)
# Out:
# [9, 0, 2, 3]

# %%
#reverse items in tuple. 
#t2[start:end:step]

# %%
t2 = (1,2,3,4,5)
t2[::-1]
# Out:
# (5, 4, 3, 2, 1)

# %%
t2[::-2]
# Out:
# (5, 3, 1)

# %%
t2[::-3]
# Out:
# (5, 2)

# %%
t2[::-4]
# Out:
# (5, 1)

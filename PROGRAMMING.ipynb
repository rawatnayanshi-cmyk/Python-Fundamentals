# %% [markdown]
# SWAPPING OF TWO NUMBERS USING 3RD VARIABLES:

# %%
A = 3
B = 6
TEMP = A

A=B

B = TEMP
print("A:",A)
print("B:",B)
# Out:
# A: 6
# B: 3

# %% [markdown]
# SWAPPING OF TWO NUMBERS WITHOUT USNG THIRD VARIABLE:

# %%
A = 3
B = 2
A,B = B,A 
print("A:",A)
print("B:",B)
# Out:
# A: 2
# B: 3

# %% [markdown]
# addition of two numbers:

# %%
a = 9
b = 4
c = (a+b)
print(c)
# Out:
# 13

# %% [markdown]
# subtraction of two numbers:

# %%
a = 8
b = 2
c = (a-b)
print(c)
# Out:
# 6

# %% [markdown]
# Divison of two numbers:

# %%
a = 5
b = 10 
c = (a/b)
print(c)
# Out:
# 0.5

# %% [markdown]
# Multiplication of two numbers:

# %%
a = 3
b = 3
c = (a*b)
print(c)
# Out:
# 9

# %% [markdown]
# Modulus of two numbers:

# %%
a = 11
b = 5
c = (a%b)
print(c)
# Out:
# 1

# %% [markdown]
# Floor division operator

# %%
a = 11
b = 5
c = (a//b)
print(c)
# Out:
# 2

# %% [markdown]
# Area of circle

# %%
r = 2
areaofcircle = 22/7*r*r
print(areaofcircle)
# Out:
# 12.571428571428571

# %% [markdown]
# Area of square

# %%
r = 2
areaofsquare = r*r
print(areaofsquare)
# Out:
# 4

# %% [markdown]
# Area of rectangle

# %%
a = 4
b = 6
areaofrectangle = a*b
print(areaofrectangle)
# Out:
# 24

# %%
a = int(input("enter a number:"))
b = int(input("enter a number:"))
c = a+b
print(c)
# Out:
# enter a number: 8520
# enter a number: 520
# 9040

# %%
num1 = int(input("enter a number:"))
num2 = int(input("enter a number:"))
num3 = num1+num2
print("sum of numbers:",num3)
# Out:
# enter a number: 500
# enter a number: 8520
# sum of numbers: 9020

# %%
#write a progrramme for finding simple interest.
p = 4000
r = 200
t = 2
si = p*r*t/100
print(si)
# Out:
# 16000.0

# %%
p =  int(input("enter a number:"))
r =  int(input("enter a number:"))
t =  int(input("enter a number:"))
si = p*r*t/100
print("simple interest:",si)
# Out:
# enter a number: 500
# enter a number: 200
# enter a number: 2
# simple interest: 2000.0

# %%
#convert celcius to farenheiht\
c = 34
d = c*1.8+32
print(d)
# Out:
# 93.2

# %%
c = 40
d = c*1.8+32
print(d)
# Out:
# 104.0

# %%
#conditional statements: write a programme to chk greatest b/w two numbers.
a = 2 
b = 10 
if (a<b):
    print("a is smaller than b")
# Out:
# a is smaller than b

# %%
a = 2
b = 10 
if (a>b):
    print("a is smaller than b")
else:
    print("a is greater then b")
# Out:
# a is greater then b

# %%
a = 20 
b = 10 
if (a>b):
    print("a is greater than b")
else:
    print("a is smaller than b")
# Out:
# a is greater than b

# %%
a = 3
b = 2
if (a>b):
    print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 10
b = 20
c = 30 
if (a>b):
    print("a is greater than b")
elif(b>c):
    print("b is greater than c")
else:
    print("c is greater than a")
# Out:
# c is greater than a

# %%
a = 2
b = 4
c = 6
if (a>b) and (a>c):
    print("a is largest number")
elif(b>a) and (b>c):
    print("b is largest number")
else:
    print("c is largest number")
# Out:
# c is largest number

# %%
a =  int(input("enter any number :"))
b =  int(input("enter any number :"))
c =  int(input("enter any number :"))
if (a>b) and (a>c):
    print("a is largest number")
elif(b>a) and (b>c):
    print("b is largest number")
else:
    print("c is largest number")
# Out:
# enter any number : 5
# enter any number : 4
# enter any number : 2
# a is largest number

# %%
score = int(input("enter any number :"))
if score >= 90:
    print("grade: A")
elif score >= 80:
    print("grade: B")
elif score >= 70:
    print("grade: C")
elif score >= 60:
    print("grade: D")
else:
    print("fail")
# Out:
# enter any number : 50
# fail

# %% [markdown]
# Wap to chk eligibiliy for vote.

# %%
a = int(input("enter any number :"))
if (a>=18):
    print("eligible for vote")
else:
    print("not eligible for vote")
# Out:
# enter any number : 18
# eligible for vote

# %% [markdown]
# Wap to chk whether the given character is vowel or consonent.

# %%
wap = input("enter a character :")
if wap in ("A","E","I","O","U"):
    print("vowel")
else:
    print("consonent")

# %% [markdown]
# Wap to chk wether the given no is even or odd.

# %%
num = int(input("enter a number:"))
if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# enter a number: 8
# even

# %% [markdown]
# Wap to chk whether the given no is positive negative or 0.

# %%
a = int(input("enter a number:"))
if a>0:
    print("positive")
elif a<0 :
    print("negative")
else:
    print("zero")
# Out:
# enter a number: -1
# negative

# %% [markdown]
# Wap to chk whether the given year is leap year or not.

# %%
year = int(input("enter a year :"))
if year % 4 == 0 and (year % 100 != 0  or year % 400 == 0):
    print("leap year")
else:
    print("not a leap year")
# Out:
# enter a year : 2026
# not a leap year

# %% [markdown]
# Wap for simple calculator.

# %%
num1 = int(input("enter a number :"))
num2 = int(input("enter a number :"))
num3 = int(input("enter a number :"))
num4 = int(input("enter a number :"))     
num = int(input("enter  1.for Addition  2. for Subtraction  3. for Division  4. for Multiplication "))
if (num==1):
    num = num1+num1
if (num==2):
    num = num2-num2
if (num==3):
   num = num3/num3
if (num==4):
  num = num3*num3
print(num)
# Out:
# enter a number : 2
# enter a number : 4
# enter a number : 8
# enter a number : 8
# enter  1.for Addition  2. for Subtraction  3. for Division  4. for Multiplication  3
# 1.0
